# %%
import numpy as np
import sympy as sp
import math

def deltaV_design(phi, alpha, altitude, launchsite, losses):
    mu_e = 398600.5
    r_e = 6378.137
    V_bo = np.sqrt(mu_e/(r_e+altitude))
    beta = np.degrees(np.arcsin(np.cos(np.radians(alpha))/np.cos(np.radians(launchsite))))
    V_ls = 465.1*np.cos(np.radians(launchsite))/1000
    dV_gl = np.sqrt((2*mu_e*altitude)/(r_e*(r_e+altitude)))
    dV_needed = np.array([-V_bo*np.cos(np.radians(phi))*np.cos(np.radians(beta)), V_bo*np.cos(np.radians(phi))*np.sin(np.radians(beta)), V_bo*np.sin(np.radians(phi))]) + np.array([0, -V_ls, dV_gl])
    dV_design = np.linalg.norm(dV_needed) + losses
    return dV_design

alt=[800, 850, 900, 950, 1000, 1100, 1200]
alpha=[30, 32, 35, 40, 45, 52, 52] #inclination
phi=0 #circular orbit so flight path angle is assumed close to zero 
launchsite=28 #kenedy space center
loss=.9
for k in range(np.size(alt)):
    print("\nFor altitude = ", alt[k])
    for i in range(np.size(alpha)):
        print('If alpha(inclination) is:', alpha[i], 'then Vdeesign is:',round(deltaV_design(phi,alpha[i],alt[k],launchsite,loss),3))
# Out:
# For altitude =  800
# If alpha(inclination) is: 30 then Vdeesign is: 8.877
# If alpha(inclination) is: 32 then Vdeesign is: 8.884
# If alpha(inclination) is: 35 then Vdeesign is: 8.897
# If alpha(inclination) is: 40 then Vdeesign is: 8.92
# If alpha(inclination) is: 45 then Vdeesign is: 8.945
# If alpha(inclination) is: 52 then Vdeesign is: 8.985
# If alpha(inclination) is: 52 then Vdeesign is: 8.985
#
# For altitude =  850
# If alpha(inclination) is: 30 then Vdeesign is: 8.902
# If alpha(inclination) is: 32 then Vdeesign is: 8.91
# If alpha(inclination) is: 35 then Vdeesign is: 8.922
# If alpha(inclination) is: 40 then Vdeesign is: 8.945
# If alpha(inclination) is: 45 then Vdeesign is: 8.97
# If alpha(inclination) is: 52 then Vdeesign is: 9.009
# If alpha(inclination) is: 52 then Vdeesign is: 9.009
#
# For altitude =  900
# If alpha(inclination) is: 30 then Vdeesign is: 8.927
# If alpha(inclination) is: 32 then Vdeesign is: 8.935
# If alpha(inclination) is: 35 then Vdeesign is: 8.947
# If alpha(inclination) is: 40 then Vdeesign is: 8.97
# If alpha(inclination) is: 45 then Vdeesign is: 8.995
# If alpha(inclination) is: 52 then Vdeesign is: 9.033
# If alpha(inclination) is: 52 then Vdeesign is: 9.033
#
# For altitude =  950
# If alpha(inclination) is: 30 then Vdeesign is: 8.951
# If alpha(inclination) is: 32 then Vdeesign is: 8.959
# If alpha(inclination) is: 35 then Vdeesign is: 8.971
# If alpha(inclination) is: 40 then Vdeesign is: 8.994
# If alpha(inclination) is: 45 then Vdeesign is: 9.019
# If alpha(inclination) is: 52 then Vdeesign is: 9.057
# If alpha(inclination) is: 52 then Vdeesign is: 9.057
#
# For altitude =  1000
# If alpha(inclination) is: 30 then Vdeesign is: 8.975
# If alpha(inclination) is: 32 then Vdeesign is: 8.983
# If alpha(inclination) is: 35 then Vdeesign is: 8.995
# If alpha(inclination) is: 40 then Vdeesign is: 9.018
# If alpha(inclination) is: 45 then Vdeesign is: 9.042
# If alpha(inclination) is: 52 then Vdeesign is: 9.081
# If alpha(inclination) is: 52 then Vdeesign is: 9.081
#
# For altitude =  1100
# If alpha(inclination) is: 30 then Vdeesign is: 9.022
# If alpha(inclination) is: 32 then Vdeesign is: 9.03
# If alpha(inclination) is: 35 then Vdeesign is: 9.042
# If alpha(inclination) is: 40 then Vdeesign is: 9.064
# If alpha(inclination) is: 45 then Vdeesign is: 9.089
# If alpha(inclination) is: 52 then Vdeesign is: 9.126
# If alpha(inclination) is: 52 then Vdeesign is: 9.126
#
# For altitude =  1200
# If alpha(inclination) is: 30 then Vdeesign is: 9.068
# If alpha(inclination) is: 32 then Vdeesign is: 9.075
# If alpha(inclination) is: 35 then Vdeesign is: 9.087
# If alpha(inclination) is: 40 then Vdeesign is: 9.109
# If alpha(inclination) is: 45 then Vdeesign is: 9.133
# If alpha(inclination) is: 52 then Vdeesign is: 9.171
# If alpha(inclination) is: 52 then Vdeesign is: 9.171
